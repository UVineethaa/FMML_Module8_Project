# %% [markdown]
# <a href="https://colab.research.google.com/github/UVineethaa/FMML_Module8_Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 15:25:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  60.7MB/s    in 1.1s
#
# 2024-03-28 15:26:04 (60.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25728  1511.04240v1  This paper presents a framework for rigid poin...    cs
# 39020  1612.00343v2  In this paper, we propose a novel curvature-pe...    cs
# 7188   1710.11383v2  We consider the problem of training generative...    cs
# 36493   1402.5205v1  Computational Grids are a new trend in distrib...    cs
# 22691  1704.05786v2  Variational inference approximates the posteri...  stat
# ...             ...                                                ...   ...
# 37984   1107.4976v2  In recent years, a rich variety of shrinkage p...  stat
# 27994  1705.02949v1  In this paper we propose a novel approach for ...    cs
# 21845   1305.7344v1  In systems biomedicine, an experimenter encoun...  stat
# 22461  1608.01234v3  We study the problem of demixing a pair of spa...  stat
# 10836   1408.6032v1  Many applications in translational medicine re...  stat
#
#                                                    title  year  \
# 25728  An Adaptive Data Representation for Robust Poi...  2015
# 39020  Global Minimum for a Finsler Elastica Minimal ...  2016
# 7188   Flexible Prior Distributions for Deep Generati...  2017
# 36493  A Survey on Dynamic Job Scheduling in Grid Env...  2014
# 22691  Importance Sampled Stochastic Optimization for...  2017
# ...                                                  ...   ...
# 37984             Generalized Beta Mixtures of Gaussians  2011
# 27994  Object Detection by Spatio-Temporal Analysis a...  2017
# 21845  Joint Modeling and Registration of Cell Popula...  2013
# 22461  Fast Algorithms for Demixing Sparse Signals fr...  2016
# 10836  Inference of Cancer Progression Models with Bi...  2014
#
#                                                 keywords
# 25728  [framework, registration, continuous, represen...
# 39020  [curvature, penalized, orientation, differenti...
# 7188   [generative, generators, deterministic, advant...
# 36493  [computational, distributed, computing, geogra...
# 22691  [variational, inference, approximates, posteri...
# ...                                                  ...
# 37984  [shrinkage, addressing, regression, expressed,...
# 27994  [detecting, background, additional, background...
# 21845  [biomedicine, experimenter, encounters, differ...
# 22461  [nonlinear, observations, superposition, mathe...
# 10836  [applications, translational, understanding, a...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25728    [framework, registration, continuous, represen...
# 39020    [curvature, penalized, orientation, differenti...
# 7188     [generative, generators, deterministic, advant...
# 36493    [computational, distributed, computing, geogra...
# 22691    [variational, inference, approximates, posteri...
#                                ...
# 1410     [represent, corresponding, transformation, pra...
# 28890    [convolutional, convolution, essentially, vect...
# 4054     [methodology, introduced, arbitrary, deformati...
# 31742    [regularization, parameters, measurements, reg...
# 37761    [partially, environments, declarative, informa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8806 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c24d9a9d-4536-4b6c-a5e6-ca8cdb4d52c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c24d9a9d-4536-4b6c-a5e6-ca8cdb4d52c6")) {                    Plotly.newPlot(                        "c24d9a9d-4536-4b6c-a5e6-ca8cdb4d52c6",                        [{"x":["framework","parametrised","robustness","approaches","iterative","continuous","reconstruction","convergence","representation","subsequently","parametrisation","minimises","constructed","registration","approximating","occlusions","demonstrated","efficient","representations","evaluation","algorithm","techniques","classical","detection","riemannian","introduce","asymmetric","experiments","penalized","steerable","promising","dependent","anisotropic","successful","orientation","minimization","synthetic","differential","penalization","curvature","essentially","interpret","extraction","functions","perceptual","efficiently","dimension","applications","numerical","structure","generators","generative","demonstrate","generalization","distributions","deterministic","advantageous","automatic","scheduling","increases","extending","potential","accessible","subsystem","intensive","computational","integrated","computing","geographically","selecting","algorithms","scheduled","throughput","environment","heuristic","sensitive","distributed","resources","utilization","boundaries","particular","solutions","approximates","importance","stochastic","justifiable","parameters","gradients","considering","outperforms","arbitrary","variational","programming","distribution","differentiable","estimates","inference","parameterized","maximizing","languages","posterior","evaluated","probabilistic","practical","optimization","consequently","approximation","generating","optimizing","conditional","sequentially","adversarial","summarization","challenging","autoregressive","originally","realistic","typically","generation","validation","likelihood","surrounding","additionally","conditioned","quantitatively","unconditional","explicitly","indicative","benchmarks","translation","generator","generated","qualitatively","sequences","perplexity","conditioning","outperform","appropriate","distortions","reduction","resilient","performance","classification","distortion","distorted","investigate","determined","different","neighbors","progressively","dependencies","architectures","represent","substantially","dimensional","broadcast","diffusion","effectiveness","performances","discriminative","demonstrates","introduces","convolutional","extensive","information","segmentation","representational","generally","objective","increasing","application","inserting","accumulated","concentrate","respective","properties","theoretical","asymptotic","exponential","empirically","regarding","understanding","significant","established","classifiers","misclassification","unquestionable","effective","hypotheses","immediate","significance","previously","classifier","simplicity","hypothesis","significantly","approximately","probability","expectation","performed"],"y":[528,3,98,461,63,104,87,111,387,28,2,3,57,29,20,21,100,394,243,242,807,359,84,363,8,299,13,622,5,5,124,84,6,85,26,61,127,26,2,15,17,25,141,209,28,173,70,431,78,323,12,117,548,109,111,43,5,204,21,44,29,139,13,4,37,300,52,126,2,40,576,3,13,121,56,55,111,63,11,42,264,139,10,93,121,1,242,37,61,280,81,58,117,218,20,76,192,23,21,103,32,150,137,165,352,45,114,97,49,88,18,97,20,279,5,17,67,106,143,48,56,16,70,17,25,1,69,4,105,108,39,175,19,85,8,16,98,87,13,95,8,902,526,21,8,137,44,735,20,13,50,122,110,40,186,7,20,220,55,95,53,72,399,167,696,211,12,66,160,104,249,3,4,12,13,201,158,15,52,81,44,158,257,48,125,13,1,263,32,9,21,93,136,29,52,281,34,174,32,130],"type":"bar"},{"x":["framework"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07309208169115013)
# 	challenging (0.09996417054819061)
# 	information (0.24937298459333573)
# 	architecture (0.09243998566821927)
# 	representation (0.13865997850232892)
# 	segmentation (0.07560014331780723)
# 	detection (0.13006091006807596)
# 	different (0.26334647079899676)
# 	recognition (0.14224292368326766)
# 	convolutional (0.1429595127194554)
#
# Some Statistics words are:
# 	statistical (0.15579890492782478)
# 	variables (0.14385266301642607)
# 	stochastic (0.13787954206072672)
# 	distribution (0.1796913887506222)
# 	algorithm (0.39621702339472376)
# 	estimation (0.1826779492284719)
# 	theoretical (0.16625186660029864)
# 	inference (0.1986062717770035)
# 	dimensional (0.19661523145843704)
# 	regression (0.17620706819313092)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="486efdb1-3e9a-4192-acc7-c969ee26660c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("486efdb1-3e9a-4192-acc7-c969ee26660c")) {                    Plotly.newPlot(                        "486efdb1-3e9a-4192-acc7-c969ee26660c",                        [{"x":["framework","parametrised","robustness","approaches","iterative","continuous","reconstruction","convergence","representation","subsequently","parametrisation","minimises","constructed","registration","approximating","occlusions","demonstrated","efficient","representations","evaluation","algorithm","techniques","classical","detection","riemannian","introduce","asymmetric","experiments","penalized","steerable","promising","dependent","anisotropic","successful","orientation","minimization","synthetic","differential","penalization","curvature","essentially","interpret","extraction","functions","perceptual","efficiently","dimension","applications","numerical","structure","generators","generative","demonstrate","generalization","distributions","deterministic","advantageous","automatic","scheduling","increases","extending","potential","accessible","subsystem","intensive","computational","integrated","computing","geographically","selecting","algorithms","scheduled","throughput","environment","heuristic","sensitive","distributed","resources","utilization","boundaries","particular","solutions","approximates","importance","stochastic","justifiable","parameters","gradients","considering","outperforms","arbitrary","variational","programming","distribution","differentiable","estimates","inference","parameterized","maximizing","languages","posterior","evaluated","probabilistic","practical","optimization","consequently","approximation","generating","optimizing","conditional","sequentially","adversarial","summarization","challenging","autoregressive","originally","realistic","typically","generation","validation","likelihood","surrounding","additionally","conditioned","quantitatively","unconditional","explicitly","indicative","benchmarks","translation","generator","generated","qualitatively","sequences","perplexity","conditioning","outperform","appropriate","distortions","reduction","resilient","performance","classification","distortion","distorted","investigate","determined","different","neighbors","progressively","dependencies","architectures","represent","substantially","dimensional","broadcast","diffusion","effectiveness","performances","discriminative","demonstrates","introduces","convolutional","extensive","information","segmentation","representational","generally","objective","increasing","application","inserting","accumulated","concentrate","respective","properties","theoretical","asymptotic","exponential","empirically","regarding","understanding","significant","established","classifiers","misclassification","unquestionable","effective","hypotheses","immediate","significance","previously","classifier","simplicity","hypothesis","significantly","approximately","probability","expectation","performed","graphical","parameter","available","tractable","maximization","converges","optimizations","estimation","complexity","associated","annotations","annotated","annotation","segmented","interactive","recognition","effectively","annotating","acquisition","ingredients","conveniently","illumination","experimented","completely","underlying","perturbation","noticeably","derivative","empirical","furthermore","understood","landscape","adversaries","propagating","functional","susceptible","eigenvalues","validated","pervasive","hierarchical","maintaining","perspective","overcomes","conjugate","inferences","efficiency","presented","propagation","reasoning","relations","qualitative","components","se ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	purchasing
# 	individualized
# 	superposed
# 	seasonality
# 	collaborators
# 	transelliptical
# 	epidemics
# 	breaching
# 	parametrically
# 	hypernetwork
# 	hypernetworks
# 	heteroscedasticity
# 	epigenomics
# 	amortization
# 	preventive
# 	omnipresent
# 	exponents
# 	decouples
# 	criminology
# 	supersparse
# Some words which never appear in Statistics papers:
# 	parametrised
# 	occlusions
# 	steerable
# 	subsystem
# 	annotating
# 	illumination
# 	transmissions
# 	underwater
# 	collaborations
# 	animation
# 	satisficing
# 	reflective
# 	reconciling
# 	curiosity
# 	implicature
# 	retrieves
# 	discontinuities
# 	contrasts
# 	aberration
# 	organisational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081759068076058e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
